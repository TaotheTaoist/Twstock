# %%
from time import sleep
import numpy as np
import matplotlib.pyplot as plt #py -m install mataplotlib
import pandas as pd  #py -m install pandas
import io
import inspect
from datetime import datetime
from pandasql import sqldf, load_births
import requests  #pip3 -m install requests. Make sure to link pip3 to environment variable path
import os
import sqlite3
import seaborn as sns
import time
import glob
import os.path
from pathlib import Path
import pandas as pd
C = pd.read_excel('https://query.data.world/s/u3hrm77dmbvkrrmq7p6dmu2dmpg7cu', engine='openpyxl')

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.DataFrame(C)

# %%
pd.set_option('display.min_rows', 100)

# %%
df.head(118)
# Out:
#                                               case  \
# 0                            Molson Coors shooting
# 1               Jersey City kosher market shooting
# 2                    Pensacola Naval base shooting
# 3                    Odessa-Midland shooting spree
# 4           Dayton entertainment district shooting
# 5                    El Paso Walmart mass shooting
# 6                  Gilroy garlic festival shooting
# 7       Virginia Beach municipal building shooting
# 8               Harry Pratt Co. warehouse shooting
# 9                  Pennsylvania hotel bar shooting
# 10                          SunTrust bank shooting
# 11                         Mercy Hospital shooting
# 12                Thousand Oaks nightclub shooting
# 13                 Tree of Life synagogue shooting
# 14                     Rite Aid warehouse shooting
# 15                           T&T Trucking shooting
# 16                     Fifth Third Center shooting
# ...

# %%
df.iloc[6][15]
# Out:
# '-'

# %%
df['gender'][1]
# Out:
# '-'

# %%
df.loc[2,'race'].replace('-','Black', 1)
# Out:
# 'black'

# %%
df['race'][2] = 'Black' #this work
df['race'][6] = 'White'
df['race'][12]= 'White'
df['race'][34]= 'Middle Eastern'
df['race'][37]= 'Middle Eastern'
df['race'][40]= 'Middle Eastern'
df['race'][43]= 'White'
df['race'][44]= 'Middle Eastern'
df['race'][68]= 'White'
df['race'][98]= 'White'

#gender
df['gender'][1] = 'M'
df['gender'][21] = 'F'
# Out:
# <ipython-input-68-dda62eb42559>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race'][2] = 'Black' #this work
# <ipython-input-68-dda62eb42559>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race'][6] = 'White'
# <ipython-input-68-dda62eb42559>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race'][12]= 'White'
# <ipython-input-68-dda62eb42559>:4: SettingWithCopyWarning:
# ...

# %%
df['location.1'][1] = 'Street'
df['location.1'][3] = 'Street'
df['location.1'][4] = 'Bar'
df['location.1'][6] = 'Festival'
df['location.1'][9] = 'Street'
df['location.1'][12] = 'Bar'
df['location.1'][19] = 'Bar'
df['location.1'][23] = 'Street'
df['location.1'][22] = 'Car_Wash'
df['location.1'][27] = 'Open Area'
df['location.1'][32] = 'Street'
df['location.1'][34] = 'Mall'
df['location.1'][35] = 'Street'
df['location.1'][36] = 'Street'
df['location.1'][37] = 'Club/Bar'
df['location.1'][39] = 'Open Area'
df['location.1'][40] = 'Workplace'
df['location.1'][42] = 'Street'
df['location.1'][46] = 'Street'
df['location.1'][50] = 'Fired into building'
df['location.1'][52] = 'Building'
df['location.1'][53] = 'Street'
df['location.1'][54] = 'Building'
df['location.1'][55] = 'Building'
df['location.1'][58] = 'Religious Area'
df['location.1'][59] = 'Threatre'
df['location.1'][60] = 'Cafe area/none target'
df['location.1'][62] = 'Random Sauna'
df['location.1'][63] = 'Salon close area'
df['location.1'][64] = 'close area Ihop'
df['location.1'][65] = ' PArking lot open area'
df['location.1'][67] = 'close area'
df['location.1'][69] = 'school'
df['location.1'][70] = 'hospital'
df['location.1'][73] = 'Building'
df['location.1'][74] = 'Mall'
df['location.1'][75] = 'Building'
df['location.1'][77] = 'Mall'
df['location.1'][79] = 'Open Area'
df['location.1'][83] = 'club'
df['location.1'][101] = 'train open area'
df['location.1'][102] = 'Restaurant'
df['location.1'][104] = 'Closed area'
df['location.1'][108] = 'Restaurant'
df['location.1'][109] = 'Car loan'
df['location.1'][113] = 'Mall'
df['location.1'][115] = 'Mcdonald'
df['location.1'][116] = 'Club'
df['location.1'][117] = 'a Shop'
# Out:
# <ipython-input-16-441f2cc702bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location.1'][1] = 'Street'
# <ipython-input-16-441f2cc702bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location.1'][3] = 'Street'
# <ipython-input-16-441f2cc702bb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location.1'][4] = 'Bar'
# <ipython-input-16-441f2cc702bb>:4: SettingWithCopyWarning:
# ...

# %%
##AGE
df['age_of_shooter'][1] = '47'
df['age_of_shooter'][2] = '21'
# Out:
# <ipython-input-15-349d2c7c6405>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age_of_shooter'][1] = '47'
# <ipython-input-15-349d2c7c6405>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age_of_shooter'][2] = '21'

# %%
df['race']=df['race'].str.replace('white','White') #Capitalize all word in the colm
df['race']=df['race'].str.replace('black','Black')

df['gender']=df['gender'].str.replace('Male','M')
df['gender']=df['gender'].str.replace('Female','F')

# %%
df['prior_signs_mental_health_issues'][0] = 'Unclear' #Mental Issue research, Changed some unclear of mental illness into 'yes'
df['prior_signs_mental_health_issues'][1] = 'No'
df['prior_signs_mental_health_issues'][2] = 'No'
df['prior_signs_mental_health_issues'][4] = 'Yes'
df['prior_signs_mental_health_issues'][5] = 'Yes'
df['prior_signs_mental_health_issues'][6] = 'No'
df['prior_signs_mental_health_issues'][7] = 'Unclear'
df['prior_signs_mental_health_issues'][7] = 'No'
df['prior_signs_mental_health_issues'][11] = 'No'
df['prior_signs_mental_health_issues'][13] = 'No'
df['prior_signs_mental_health_issues'][14] = 'Yes'
df['prior_signs_mental_health_issues'][14] = 'No'
df['prior_signs_mental_health_issues'][17] = 'No'
df['prior_signs_mental_health_issues'][17] = 'Yes'
df['prior_signs_mental_health_issues'][23] = 'Unclear'
df['prior_signs_mental_health_issues'][22] = 'No'
df['prior_signs_mental_health_issues'][25] = 'Unclear'
df['prior_signs_mental_health_issues'][26] = 'No'
df['prior_signs_mental_health_issues'][27] = 'No'
df['prior_signs_mental_health_issues'][30] = 'Yes'
df['prior_signs_mental_health_issues'][36] = 'Yes'
df['prior_signs_mental_health_issues'][38] = 'Yes'
df['prior_signs_mental_health_issues'][41] = 'Yes'
df['prior_signs_mental_health_issues'][42] = 'Yes'
df['prior_signs_mental_health_issues'][43] = 'Yes'
df['prior_signs_mental_health_issues'][44] = 'Yes'
df['prior_signs_mental_health_issues'][47] = 'No'  #revenge
df['prior_signs_mental_health_issues'][49] = 'Yes'
df['prior_signs_mental_health_issues'][50] = 'No'
df['prior_signs_mental_health_issues'][52] = 'No'
# Out:
# <ipython-input-11-2aba32775b81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prior_signs_mental_health_issues'][0] = 'Unclear' #Mental Issue research, Changed some unclear of mental illness into 'yes'
# <ipython-input-11-2aba32775b81>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prior_signs_mental_health_issues'][1] = 'No'
# <ipython-input-11-2aba32775b81>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.to_csv('Shooting.csv', index=False,)

# %%
timedf= df[['total_victims','year']]

# %%
time_df = timedf.set_index('year')

# %%
plt.xlabel("Year")
plt.ylabel("Number of Victims")
plt.plot(time_df)

# %%
df["age_of_shooter"] = pd.to_numeric(df["age_of_shooter"]) #Average shooter age, so once you pass the age of 34, you are less likely to become a seiral killer
df["age_of_shooter"].mean()
# Out:
# 34.33898305084746

# %%
dfsort = df[['case','location','date','summary','fatalities','injured','total_victims','location.1','age_of_shooter','prior_signs_mental_health_issues','race','gender','latitude','longitude','year']]

# %%
dfsort
# Out:
#                                               case  \
# 0                            Molson Coors shooting
# 1               Jersey City kosher market shooting
# 2                    Pensacola Naval base shooting
# 3                    Odessa-Midland shooting spree
# 4           Dayton entertainment district shooting
# 5                    El Paso Walmart mass shooting
# 6                  Gilroy garlic festival shooting
# 7       Virginia Beach municipal building shooting
# 8               Harry Pratt Co. warehouse shooting
# 9                  Pennsylvania hotel bar shooting
# 10                          SunTrust bank shooting
# 11                         Mercy Hospital shooting
# 12                Thousand Oaks nightclub shooting
# 13                 Tree of Life synagogue shooting
# 14                     Rite Aid warehouse shooting
# 15                           T&T Trucking shooting
# 16                     Fifth Third Center shooting
# ...

# %%
sns.pairplot(dfsort)

# %%
sns.distplot(dfsort['age_of_shooter'])
# Out:
# <AxesSubplot:xlabel='age_of_shooter', ylabel='Density'>

# %%
dfsort.corr()
# Out:
#                 fatalities   injured  total_victims  age_of_shooter  latitude  \
# fatalities        1.000000  0.662726       0.738192        0.038683 -0.205655
# injured           0.662726  1.000000       0.994394        0.172404 -0.052710
# total_victims     0.738192  0.994394       1.000000        0.160767 -0.076520
# age_of_shooter    0.038683  0.172404       0.160767        1.000000 -0.093061
# latitude         -0.205655 -0.052710      -0.076520       -0.093061  1.000000
# longitude         0.018597 -0.114283      -0.100323        0.093941 -0.072948
# year             -0.001277  0.068791       0.061788       -0.124564  0.100489
#
#                 longitude      year
# fatalities       0.018597 -0.001277
# injured         -0.114283  0.068791
# total_victims   -0.100323  0.061788
# age_of_shooter   0.093941 -0.124564
# latitude        -0.072948  0.100489
# longitude        1.000000  0.029367
# year             0.029367  1.000000
